# %%
import sklearn
from sklearn import datasets
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = datasets.load_iris()

# %%
data.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df = pd.DataFrame(
    data=data.data,
    columns=["_".join(x.split(" ")[:2]) for x in data.feature_names],
)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df["target"] = data.target
df["target_name"] =[data.target_names[x] for x in df["target"]]
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target target_name
# 0             5.1          3.5           1.4          0.2       0      setosa
# 1             4.9          3.0           1.4          0.2       0      setosa
# 2             4.7          3.2           1.3          0.2       0      setosa
# 3             4.6          3.1           1.5          0.2       0      setosa
# 4             5.0          3.6           1.4          0.2       0      setosa
# ..            ...          ...           ...          ...     ...         ...
# 145           6.7          3.0           5.2          2.3       2   virginica
# 146           6.3          2.5           5.0          1.9       2   virginica
# 147           6.5          3.0           5.2          2.0       2   virginica
# 148           6.2          3.4           5.4          2.3       2   virginica
# 149           5.9          3.0           5.1          1.8       2   virginica
#
# [150 rows x 6 columns]

# %%
df["target_name"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='target_name'>

# %%
df.plot(kind = "scatter", x = "petal_width", y = "sepal_width")
# Out:
# <Axes: xlabel='petal_width', ylabel='sepal_width'>

# %%
df["petal_length"].plot(kind = "kde")
# Out:
# <Axes: ylabel='Density'>

# %%
sns.pairplot(df, hue="target_name",)
